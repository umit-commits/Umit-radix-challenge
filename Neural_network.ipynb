# %% [markdown]
# <a href="https://colab.research.google.com/github/umit-commits/Umit-radix-challenge/blob/main/Neural_network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/train.csv')

# %%
df
# Out:
#        movie_id  year                                           synopsis  \
# 0             0  2005  Cruel But Necessary is the story of Betty Muns...
# 1             1  2012  Yorkshire, 1974, the Maynard family moves into...
# 2             2  2017  When a renowned architecture scholar falls sud...
# 3             3  1996  The story dealt with Lord Rama and his retalia...
# 4             4  2003  A Thai playboy cons a girl into bed and then l...
# ...         ...   ...                                                ...
# 37664     37664  1954  A botanical expedition to the Himalayas captur...
# 37665     37665  1962  The private life of Hitler revealed for the fi...
# 37666     37666  2017  A nonfiction account of the Ferguson uprising ...
# 37667     37667  1990  Documentary examining Bokassa's rule in the Ce...
# 37668     37668  2014  A soldier introduces himself to the Peterson f...
#
#                              genres
# 0                             Drama
# ...

# %%
data_df = pd.DataFrame(df)
data_df
# Out:
#        movie_id  year                                           synopsis  \
# 0             0  2005  Cruel But Necessary is the story of Betty Muns...
# 1             1  2012  Yorkshire, 1974, the Maynard family moves into...
# 2             2  2017  When a renowned architecture scholar falls sud...
# 3             3  1996  The story dealt with Lord Rama and his retalia...
# 4             4  2003  A Thai playboy cons a girl into bed and then l...
# ...         ...   ...                                                ...
# 37664     37664  1954  A botanical expedition to the Himalayas captur...
# 37665     37665  1962  The private life of Hitler revealed for the fi...
# 37666     37666  2017  A nonfiction account of the Ferguson uprising ...
# 37667     37667  1990  Documentary examining Bokassa's rule in the Ce...
# 37668     37668  2014  A soldier introduces himself to the Peterson f...
#
#                              genres
# 0                             Drama
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

X = data_df['synopsis'].values
y = data_df['genres'].values

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.regularizers import l2
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# Tokenize input texts
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
X_encoded = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(X_encoded, padding='post')

# %%
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=128, input_length=X_padded.shape[1]))
model.add(LSTM(64, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01), return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(32, kernel_regularizer=l2(0.01), recurrent_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(Dropout(0.2))
model.add(Dense(64, activation='relu', kernel_regularizer=l2(0.01), bias_regularizer=l2(0.01)))
model.add(Dense(len(set(y_encoded)), activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 188, 128)          9506688
#
#  lstm (LSTM)                 (None, 188, 64)           49408
#
#  dropout (Dropout)           (None, 188, 64)           0
#
#  lstm_1 (LSTM)               (None, 188, 64)           33024
#
#  dropout_1 (Dropout)         (None, 188, 64)           0
#
#  lstm_2 (LSTM)               (None, 32)                12416
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 64)                2112
#
#  dense_1 (Dense)             (None, 1198)              77870
#
# ...
# Total params: 9681518 (36.93 MB)
# Trainable params: 9681518 (36.93 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X_train, X_val, y_train, y_val = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42)

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 942/942 [==============================] - 581s 609ms/step - loss: 5.5017 - accuracy: 0.1477 - val_loss: 4.5227 - val_accuracy: 0.1489
# Epoch 2/100
# 942/942 [==============================] - 557s 591ms/step - loss: 4.3995 - accuracy: 0.1513 - val_loss: 4.4031 - val_accuracy: 0.1489
# Epoch 3/100
# 942/942 [==============================] - 553s 587ms/step - loss: 4.3388 - accuracy: 0.1513 - val_loss: 4.3929 - val_accuracy: 0.1489
# Epoch 4/100
# 789/942 [========================>.....] - ETA: 1:23 - loss: 4.3177 - accuracy: 0.1505
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-d6b710f4eb98> in <cell line: 1>()
# ----> 1 history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
# ...
